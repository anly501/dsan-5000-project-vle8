# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../Web-Scraping-Stats/cleaned_stats_data/player_stats_combined.csv", index_col=False)
df.rename(columns={'X3P':'ThreeP', 'X3PA': 'ThreeP_Attempted', 'X3P.': 'ThreeP_Percentage', 'FG.': 'FG_Percentage', 'FT.': 'FT_Percentage'}, inplace=True)
df['MP'] = df['MP'].str.split(':').str[0].astype(int)
df.head()
# Out:
#          Players   Tm  MP  FG  FGA  ThreeP  ThreeP_Attempted  FT  FTA  ORB  \
# 0  George Gervin  SAS  40  14   26       0                 0   6    9    4
# 1  Eddie Johnson  ATL  32  11   16       0                 0   0    0    1
# 2   Moses Malone  HOU  31   7   12       0                 0   6   12    6
# 3  Julius Erving  PHI  20   4   12       0                 0   3    4    2
# 4      John Drew  ATL  15   0    4       0                 0   4    5    1
#
#    ...  BLK  TOV  PF  PTS  FG_Percentage  ThreeP_Percentage  FT_Percentage  \
# 0  ...    0    3   2   34          0.538                NaN          0.667
# 1  ...    0    2   2   22          0.688                NaN            NaN
# 2  ...    2    5   4   20          0.583                NaN          0.500
# 3  ...    1    2   5   11          0.333                NaN          0.750
# 4  ...    0    3   5    4          0.000                NaN          0.800
#
#    Player_Type  Region  Year
# 0      Starter    East  1980
# ...

# %%
Game_1980s = df[df['Year'].between(1980,1989)]
Game_1990s = df[df['Year'].between(1990,1999)]
Game_2000s = df[df['Year'].between(2000,2009)]

# %%
#  QUESTION 1
print("Average Points Per Player in 1980s =", round(Game_1980s['PTS'].mean()), "points")
print("Average Points Per Player in 1990s =", round(Game_1990s['PTS'].mean()), "points")
print("Average Points Per Player in 2000s =", round(Game_2000s['PTS'].mean()), "points")
print("Overall Average Points Per Player =", round(df['PTS'].mean()), "points")
# Out:
# Average Points Per Player in 1980s = 12 points
# Average Points Per Player in 1990s = 10 points
# Average Points Per Player in 2000s = 11 points
# Overall Average Points Per Player = 11 points

# %%
# QUESTION 1 VISUAL
average_points_per_year = df.groupby(['Year'])['PTS'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='PTS', data=average_points_per_year, errorbar=None, palette='viridis')
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.ylabel('Average Points per Player')
plt.title('Average Points per Player by Year')
plt.axhline(y=11, color='red', linestyle='--') # overall average
plt.savefig("../mysite/AvgPTS-Year.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# QUESTION 2
print("Average FG Percentage in 1980s =", round(Game_1980s['FG_Percentage'].mean()*100, 2), "%")
print("Average FG Percentage in 1990s =", round(Game_1990s['FG_Percentage'].mean()*100, 2), "%")
print("Average FG Percentage in 2000s =", round(Game_2000s['FG_Percentage'].mean()*100, 2), "%")
print("Overall Average FG Percentage =", round(df['FG_Percentage'].mean()*100, 2), "%", "\n")

print("Average FT Percentage in 1980s =", round(Game_1980s['FT_Percentage'].mean()*100, 2), "%")
print("Average FT Percentage in 1990s =", round(Game_1990s['FT_Percentage'].mean()*100, 2), "%")
print("Average FT Percentage in 2000s =", round(Game_2000s['FT_Percentage'].mean()*100, 2), "%")
print("Overall Average FT Percentage =", round(df['FT_Percentage'].mean()*100, 2), "%", "\n")

print("Average Three Point Percentage in 1980s =", round(Game_1980s['ThreeP_Percentage'].mean()*100, 2), "%")
print("Average Three Point Percentage in 1990s =", round(Game_1990s['ThreeP_Percentage'].mean()*100, 2), "%")
print("Average Three Point Percentage in 2000s =", round(Game_2000s['ThreeP_Percentage'].mean()*100, 2), "%")
print("Overall Average Three Point Percentage =", round(df['ThreeP_Percentage'].mean()*100, 2), "%")
# Out:
# Average FG Percentage in 1980s = 47.74 %
# Average FG Percentage in 1990s = 47.44 %
# Average FG Percentage in 2000s = 48.49 %
# Overall Average FG Percentage = 48.02 %
#
# Average FT Percentage in 1980s = 74.12 %
# Average FT Percentage in 1990s = 72.07 %
# Average FT Percentage in 2000s = 61.25 %
# Overall Average FT Percentage = 69.79 %
#
# Average Three Point Percentage in 1980s = 26.63 %
# Average Three Point Percentage in 1990s = 33.27 %
# Average Three Point Percentage in 2000s = 27.32 %
# Overall Average Three Point Percentage = 29.61 %

# %%
# QUESTION 2 VISUAL
average_FG_per_year = df.groupby(['Year', 'Players'])['FG_Percentage'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='FG_Percentage', data=average_FG_per_year, errorbar=None, palette='viridis')
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.ylabel('Average Field Goal Percentage')
plt.title('Average Field Goal Percentage by Year')
plt.axhline(y=0.4802, color='red', linestyle='--') # overall average
plt.savefig("../mysite/AvgFG-Year.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# QUESTION 2 VISUAL
average_FT_per_year = df.groupby(['Year', 'Players'])['FT_Percentage'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='FT_Percentage', data=average_FT_per_year, errorbar=None, palette='viridis')
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.ylabel('Average Free Throw Percentage')
plt.title('Average Free Throw Percentage by Year')
plt.axhline(y=0.6979, color='red', linestyle='--') # overall average
plt.savefig("../mysite/AvgFT-Year.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# QUESTION 2 VISUAL
average_3P_per_year = df.groupby(['Year', 'Players'])['ThreeP_Percentage'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='ThreeP_Percentage', data=average_3P_per_year, errorbar=None, palette='viridis')
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.ylabel('Average Three Point Percentage')
plt.title('Average Three Point Percentage by Year')
plt.axhline(y=0.2961, color='red', linestyle='--') # overall average
plt.savefig("../mysite/Avg3P-Year.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# QUESTION 3A
print("Average Assists in 1980s =", round(Game_1980s['AST'].mean(), 1), "assists")
print("Average Assists in 1990s =", round(Game_1990s['AST'].mean(), 1), "assists")
print("Average Assists in 2000s =", round(Game_2000s['AST'].mean(), 1), "assists")
print("Overall Average Assists =", round(df['AST'].mean(), 1), "assists")
# Out:
# Average Assists in 1980s = 2.8 assists
# Average Assists in 1990s = 2.6 assists
# Average Assists in 2000s = 2.9 assists
# Overall Average Assists = 2.8 assists

# %%
# QUESTION 2 VISUAL
average_AST_per_year = df.groupby(['Year', 'Players'])['AST'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='AST', data=average_AST_per_year, errorbar=None, palette='viridis')
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.ylabel('Average Assists')
plt.title('Average Assists by Year')
plt.axhline(y=2.8, color='red', linestyle='--') # overall average
plt.savefig("../mysite/AvgAST-Year.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# QUESTION 3B
print("Average Rebounds in 1980s =", round(Game_1980s['TRB'].mean(), 1), "total rebounds")
print("Average Rebounds in 1990s =", round(Game_1990s['TRB'].mean(), 1), "total rebounds")
print("Average Rebounds in 2000s =", round(Game_2000s['TRB'].mean(), 1), "total rebounds")
print("Overall Average Rebounds =", round(df['TRB'].mean(), 1), "total rebounds")
# Out:
# Average Rebounds in 1980s = 4.6 total rebounds
# Average Rebounds in 1990s = 4.4 total rebounds
# Average Rebounds in 2000s = 4.6 total rebounds
# Overall Average Rebounds = 4.5 total rebounds

# %%
# QUESTION 2 VISUAL
average_TRB_per_year = df.groupby(['Year', 'Players'])['TRB'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='TRB', data=average_TRB_per_year, errorbar=None, palette='viridis')
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.ylabel('Average Rebounds')
plt.title('Average Rebounds by Year')
plt.axhline(y=4.5, color='red', linestyle='--') # overall average
plt.savefig("../mysite/AvgTRB-Year.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# QUESTION 4A
EAST_win_years = [1980, 1981, 1982, 1983, 1984, 1986, 1988, 1990, 1991, 1994, 1996, 1997, 1998, 2001, 2005, 2006, 2008, 2010]
EAST_wins = df[df['Year'].isin(EAST_win_years) & (df['Region']=="East")]
EAST_wins['Players'].value_counts()
# Out:
# Players
# Larry Bird         8
# Robert Parish      7
# Michael Jordan     6
# Julius Erving      6
# Isiah Thomas       6
#                   ..
# Chris Webber       1
# Shawn Kemp         1
# Rik Smits          1
# Jayson Williams    1
# David Lee          1
# Name: count, Length: 101, dtype: int64

# %%
# QUESTION 4A VISUAL
EAST_top_players = EAST_wins['Players'].value_counts().head(5)
plt.figure(figsize=(10, 6))
sns.barplot(x=EAST_top_players.index, y=EAST_top_players.values, palette="viridis")
plt.xlabel('Players')
plt.ylabel('Games Won')
plt.title('Top 5 East Players Game Wins From 1980-2010')
plt.savefig("../mysite/Top5-EAST.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# QUESTION 4B
WEST_win_years = [1985, 1987, 1989, 1992, 1993, 1995, 2000, 2002, 2003, 2004, 2007, 2009]
WEST_wins = df[df['Year'].isin(WEST_win_years) & (df['Region']=="West")]
WEST_wins['Players'].value_counts()
# Out:
# Players
# Hakeem Olajuwon      6
# Tim Duncan           6
# Kobe Bryant          6
# Kevin Garnett        5
# Karl Malone          5
#                     ..
# Joe Barry Carroll    1
# Rasheed Wallace      1
# Sleepy Floyd         1
# Michael Finley       1
# David West           1
# Name: count, Length: 73, dtype: int64

# %%
# QUESTION 4B VISUAL
WEST_top_players = WEST_wins['Players'].value_counts().head(5)
plt.figure(figsize=(10, 6))
sns.barplot(x=WEST_top_players.index, y=WEST_top_players.values, palette="viridis")
plt.xlabel('Players')
plt.ylabel('Games Won')
plt.title('Top 5 West Players Game Wins From 1980-2010')
plt.savefig("../mysite/Top5-WEST.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# QUESTION 6
print("Average Minutes Played in 1980s =", round(Game_1980s['MP'].mean(), 1), "minutes")
print("Average Minutes Played  in 1990s =", round(Game_1990s['MP'].mean(), 1), "minutes")
print("Average Minutes Played  in 2000s =", round(Game_2000s['MP'].mean(), 1), "minutes")
print("Overall Average Minutes Played =", round(df['MP'].mean(), 1), "minutes")
# Out:
# Average Minutes Played in 1980s = 21.1 minutes
# Average Minutes Played  in 1990s = 20.1 minutes
# Average Minutes Played  in 2000s = 20.2 minutes
# Overall Average Minutes Played = 20.4 minutes

# %%
# QUESTION 6A
total_mins =df.groupby('Players')['MP'].sum()
top_players = total_mins.sort_values(ascending=False).head(5)
print(top_players)

top_players = top_players.reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Players', y='MP', data=top_players, palette='viridis')
plt.xlabel('Players')
plt.ylabel('Total Minutes Played')
plt.title('Top 5 Players with Most Minutes Played')
plt.savefig("../mysite/SumMP-Year.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Players
# Michael Jordan    382
# Magic Johnson     331
# Isiah Thomas      318
# Kobe Bryant       295
# Larry Bird        287
# Name: MP, dtype: int64

# %%
Jordan = df[df['Players'] == "Michael Jordan"]
print(Jordan['MP'].mean())

plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='MP', data=Jordan, palette='viridis')
plt.xlabel('Year')
plt.ylabel('Minutes Played')
plt.title('Michael Jordan - Minutes Played by Year')
plt.axhline(y=29.38, color='red', linestyle='--') # average
plt.savefig("../mysite/Jordan-MP.png")
plt.show()
# Out:
# 29.384615384615383
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
Johnson = df[df['Players'] == "Magic Johnson"]
print(Johnson['MP'].mean())

plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='MP', data=Johnson, palette='viridis')
plt.xlabel('Year')
plt.ylabel('Minutes Played')
plt.title('Magic Johnson - Minutes Played by Year')
plt.axhline(y=30.09, color='red', linestyle='--') # average
plt.savefig("../mysite/Johnson-MP.png")
plt.show()
# Out:
# 30.09090909090909
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
Thomas = df[df['Players'] == "Isiah Thomas"]
print(Thomas['MP'].mean())

plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='MP', data=Thomas, palette='viridis')
plt.xlabel('Year')
plt.ylabel('Minutes Played')
plt.title('Isiah Thomas - Minutes Played by Year')
plt.axhline(y=28.91, color='red', linestyle='--') # average
plt.savefig("../mysite/Thomas-MP.png")
plt.show()
# Out:
# 28.90909090909091
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
Bryant = df[df['Players'] == "Kobe Bryant"]
print(Bryant['MP'].mean())

plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='MP', data=Bryant, palette='viridis')
plt.xlabel('Year')
plt.ylabel('Minutes Played')
plt.title('Kobe Bryant - Minutes Played by Year')
plt.axhline(y=26.82, color='red', linestyle='--') # average
plt.savefig("../mysite/Bryant-MP.png")
plt.show()
# Out:
# 26.818181818181817
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
Bird = df[df['Players'] == "Larry Bird"]
print(Bird['MP'].mean())

plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='MP', data=Bird, palette='viridis')
plt.xlabel('Year')
plt.ylabel('Minutes Played')
plt.title('Larry Bird - Minutes Played by Year')
plt.axhline(y=28.7, color='red', linestyle='--') # average
plt.savefig("../mysite/Bird-MP.png")
plt.show()
# Out:
# 28.7
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# QUESTION 7
print("Average Defensive Rebounds in 1980s =", round(Game_1980s['DRB'].mean(), 1), "rebounds")
print("Average Defensive Rebounds in 1990s =", round(Game_1990s['DRB'].mean(), 1), "rebounds")
print("Average Defensive Rebounds in 2000s =", round(Game_2000s['DRB'].mean(), 1), "rebounds")
print("Overall Average Defensive Rebounds =", round(df['DRB'].mean(), 1), "rebounds", "\n")

print("Average Steals in 1980s =", round(Game_1980s['STL'].mean(), 2), "steals")
print("Average Steals in 1990s =", round(Game_1990s['STL'].mean(), 2), "steals")
print("Average Steals in 2000s =", round(Game_2000s['STL'].mean(), 2), "steals")
print("Overall Average Steals =", round(df['STL'].mean(), 2), "steals", "\n")

print("Average Blocks in 1980s =", round(Game_1980s['BLK'].mean(), 1), "blocks")
print("Average Blocks in 1990s =", round(Game_1990s['BLK'].mean(), 1), "blocks")
print("Average Blocks in 2000s =", round(Game_2000s['BLK'].mean(), 1), "blocks")
print("Overall Average Blocks =", round(df['BLK'].mean(), 1), "blocks", "\n")

print("Average Turnovers in 1980s =", round(Game_1980s['TOV'].mean(), 1), "turnovers")
print("Average Turnovers in 1990s =", round(Game_1990s['TOV'].mean(), 1), "turnovers")
print("Average Turnovers in 2000s =", round(Game_2000s['TOV'].mean(), 1), "turnovers")
print("Overall Average Turnovers =", round(df['TOV'].mean(), 1), "turnovers", "\n")
# Out:
# Average Defensive Rebounds in 1980s = 2.9 rebounds
# Average Defensive Rebounds in 1990s = 2.9 rebounds
# Average Defensive Rebounds in 2000s = 3.0 rebounds
# Overall Average Defensive Rebounds = 2.9 rebounds
#
# Average Steals in 1980s = 1.19 steals
# Average Steals in 1990s = 1.06 steals
# Average Steals in 2000s = 1.13 steals
# Overall Average Steals = 1.13 steals
#
# Average Blocks in 1980s = 0.7 blocks
# Average Blocks in 1990s = 0.5 blocks
# Average Blocks in 2000s = 0.4 blocks
# Overall Average Blocks = 0.5 blocks
#
# Average Turnovers in 1980s = 1.9 turnovers
# Average Turnovers in 1990s = 1.7 turnovers
# Average Turnovers in 2000s = 1.6 turnovers
# Overall Average Turnovers = 1.7 turnovers

# %%
top_DRB =df.groupby('Players')['DRB'].mean()
top_DRB_players = top_DRB.sort_values(ascending=False).head(5)
print(top_DRB_players)
# Out:
# Players
# Tim Duncan            7.166667
# Tom Gugliotta         7.000000
# Jayson Williams       7.000000
# Christian Laettner    7.000000
# Brandon Roy           6.500000
# Name: DRB, dtype: float64

# %%
top_STL =df.groupby('Players')['STL'].mean()
top_STL_players = top_STL.sort_values(ascending=False).head(5)
print(top_STL_players)
# Out:
# Players
# Deron Williams    4.0
# Michael Adams     4.0
# Eddie Johnson     3.5
# Chris Paul        3.5
# Dwyane Wade       3.0
# Name: STL, dtype: float64

# %%
top_BLK =df.groupby('Players')['BLK'].mean()
top_BLK_players = top_BLK.sort_values(ascending=False).head(5)
print(top_BLK_players)
# Out:
# Players
# Elvin Hayes            4.0
# Kareem Abdul-Jabbar    2.4
# Dan Roundfield         2.0
# James Donaldson        2.0
# Horace Grant           2.0
# Name: BLK, dtype: float64

# %%
top_TOV =df.groupby('Players')['TOV'].mean()
top_TOV_players = top_TOV.sort_values(ascending=False).head(5)
print(top_TOV_players)
# Out:
# Players
# Deron Williams    5.000000
# World B. Free     5.000000
# Magic Johnson     4.363636
# Allen Iverson     4.222222
# Truck Robinson    4.000000
# Name: TOV, dtype: float64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='DRB', data=df, errorbar=None, palette='viridis')
plt.xlabel('Year')
plt.ylabel('Average Defensive Rebounds')
plt.title('Average Defensive Rebounds by Year')
plt.xticks(rotation=45)
plt.axhline(y=2.9, color='red', linestyle='--') # average
plt.savefig("../mysite/DRB.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='STL', data=df, errorbar=None, palette='viridis')
plt.xlabel('Year')
plt.ylabel('Average Steals')
plt.title('Average Steals by Year')
plt.xticks(rotation=45)
plt.axhline(y=1.1, color='red', linestyle='--') # average
plt.savefig("../mysite/STL.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='BLK', data=df, errorbar=None, palette='viridis')
plt.xlabel('Year')
plt.ylabel('Average Blocks')
plt.title('Average Blocks by Year')
plt.xticks(rotation=45)
plt.axhline(y=0.5, color='red', linestyle='--') # average
plt.savefig("../mysite/BLK.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='TOV', data=df, errorbar=None, palette='viridis')
plt.xlabel('Year')
plt.ylabel('Total Turnovers')
plt.title('Total Turnovers by Year')
plt.xticks(rotation=45)
plt.axhline(y=1.7, color='red', linestyle='--') # average
plt.savefig("../mysite/TOV.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
df2 = pd.read_csv("../Web-Scraping-Player-Details/cleaned_player_details_data/combined_dataset.csv", index_col=False)
df2.head()
# Out:
#             Player Position  Weight             Team    Nationality  \
# 0   Tiny Archibald       PG     150   Boston Celtics  United States
# 1       Larry Bird       SF     220   Boston Celtics  United States
# 2  Bill Cartwright        C     245  New York Knicks  United States
# 3      Dave Cowens       FC     230   Boston Celtics  United States
# 4        John Drew       GF     205    Atlanta Hawks  United States
#
#    Game_Year Region Selection_Type  Height_Feet  Height_Inch  \
# 0       1980   East        Coaches            6            1
# 1       1980   East        Coaches            6            9
# 2       1980   East        Coaches            7            1
# 3       1980   East        Coaches            6            9
# 4       1980   East           Fans            6            6
#
#    Height_In_Inches NBA_Draft_Year NBA_Draft_Round NBA_Draft_Pick
# 0                73           1970               2              2
# ...

# %%
merged_df = pd.merge(df, df2, left_on=['Players', 'Year', 'Region'], right_on=['Player', 'Game_Year', 'Region'], how='inner')
drop_cols = ['Tm', 'Game_Year', 'Player', 'Nationality', 'Height_Feet', 'Height_Inch', 'NBA_Draft_Year', 'NBA_Draft_Round', 'NBA_Draft_Pick']
merged_df = merged_df.drop(columns=drop_cols)
merged_df.dtypes
# Out:
# Players               object
# MP                     int64
# FG                     int64
# FGA                    int64
# ThreeP                 int64
# ThreeP_Attempted       int64
# FT                     int64
# FTA                    int64
# ORB                    int64
# DRB                    int64
# TRB                    int64
# AST                    int64
# STL                    int64
# BLK                    int64
# TOV                    int64
# PF                     int64
# PTS                    int64
# FG_Percentage        float64
# ThreeP_Percentage    float64
# FT_Percentage        float64
# Player_Type           object
# Region                object
# Year                   int64
# Position              object
# Weight                 int64
# Team                  object
# Selection_Type        object
# Height_In_Inches       int64
# dtype: object

# %%
# QUESTION 9
avg_points_by_position = merged_df.groupby('Position')['PTS'].mean().reset_index()
print(avg_points_by_position)
print("Overall Average Points =", merged_df['PTS'].mean())

plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='PTS', data=avg_points_by_position, palette='viridis')
plt.xlabel('Player Position')
plt.ylabel('Average Points')
plt.title('Average Points by Player Position')
plt.axhline(y=10.98, color='red', linestyle='--') # average
plt.savefig("../mysite/Position-PTS.png")
plt.show()
# Out:
#   Position        PTS
# 0        C  10.620438
# 1        F  12.187500
# 2       FC   8.750000
# 3        G  10.803030
# 4       GF  11.289474
# 5       PF  10.318681
# 6       PG  10.891566
# 7       SF  11.229358
# 8       SG  12.656250
# Overall Average Points = 10.984285714285715
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# QUESTION 9
avg_MP_by_position = merged_df.groupby('Position')['MP'].mean().reset_index()
print(avg_MP_by_position)
print("Overall Average Minutes Played =", merged_df['MP'].mean())

plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='MP', data=avg_MP_by_position, palette='viridis')
plt.xlabel('Player Position')
plt.ylabel('Average Minutes Played')
plt.title('Average Minutes Played by Player Position')
plt.axhline(y=20.48, color='red', linestyle='--') # average
plt.savefig("../mysite/Position-MP.png")
plt.show()
# Out:
#   Position         MP
# 0        C  19.518248
# 1        F  19.812500
# 2       FC  20.312500
# 3        G  20.818182
# 4       GF  20.131579
# 5       PF  19.318681
# 6       PG  22.313253
# 7       SF  20.568807
# 8       SG  21.458333
# Overall Average Minutes Played = 20.47714285714286
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# QUESTION 9
avg_AST_by_position = merged_df.groupby('Position')['AST'].mean().reset_index()
print(avg_AST_by_position)
print("Overall Average Three Pointer =", merged_df['AST'].mean())

plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='AST', data=avg_AST_by_position, palette='viridis')
plt.xlabel('Player Position')
plt.ylabel('Average Assists')
plt.title('Average Assists by Player Position')
plt.axhline(y=2.76, color='red', linestyle='--') # average
plt.savefig("../mysite/Position-AST.png")
plt.show()
# Out:
#   Position       AST
# 0        C  1.197080
# 1        F  2.281250
# 2       FC  1.437500
# 3        G  5.469697
# 4       GF  2.000000
# 5       PF  1.505495
# 6       PG  6.554217
# 7       SF  2.100917
# 8       SG  2.927083
# Overall Average Three Pointer = 2.762857142857143
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# QUESTION 9
avg_TRB_by_position = merged_df.groupby('Position')['TRB'].mean().reset_index()
print(avg_TRB_by_position)
print("Overall Average Rebounds =", merged_df['TRB'].mean())

plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='TRB', data=avg_TRB_by_position, palette='viridis')
plt.xlabel('Player Position')
plt.ylabel('Average Rebounds')
plt.title('Average Rebounds by Player Position')
plt.axhline(y=4.56, color='red', linestyle='--') # average
plt.savefig("../mysite/Position-TRB.png")
plt.show()
# Out:
#   Position       TRB
# 0        C  6.540146
# 1        F  5.187500
# 2       FC  7.437500
# 3        G  2.348485
# 4       GF  3.263158
# 5       PF  5.923077
# 6       PG  2.843373
# 7       SF  3.752294
# 8       SG  3.218750
# Overall Average Rebounds = 4.558571428571429
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# QUESTION 9
avg_FT_by_position = merged_df.groupby('Position')['FT_Percentage'].mean().reset_index()
print(avg_FT_by_position)
print("Overall Average Free Throw Percentage =", merged_df['FT_Percentage'].mean())

plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='FT_Percentage', data=avg_FT_by_position, palette='viridis')
plt.xlabel('Player Position')
plt.ylabel('Average Free Throw Percentage')
plt.title('Average Free Throw Percentage by Player Position')
plt.axhline(y=0.695, color='red', linestyle='--') # average
plt.savefig("../mysite/Position-FT.png")
plt.show()
# Out:
#   Position  FT_Percentage
# 0        C       0.653885
# 1        F       0.589875
# 2       FC       0.583321
# 3        G       0.689781
# 4       GF       0.780833
# 5       PF       0.704189
# 6       PG       0.775545
# 7       SF       0.714443
# 8       SG       0.737205
# Overall Average Free Throw Percentage = 0.6951373493975903
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
pd.crosstab(merged_df['Region'], merged_df['Selection_Type'])
# Out:
# Selection_Type  Coaches  Fans  Replacement
# Region
# East                198   130           19
# West                193   142           18

# %%
count_df = merged_df.groupby(['Region', 'Selection_Type']).size().reset_index(name='Count')

# Plotting with Seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Count', hue='Selection_Type', data=count_df, palette='viridis')
plt.xlabel('Region')
plt.ylabel('Count')
plt.title('Count of Selection Types by Region')
plt.savefig("../mysite/Select-Region.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
pd.pivot_table(merged_df, values='PTS', index='Position', columns='Region', aggfunc='mean', fill_value=0)
# Out:
# Region         East       West
# Position
# C         10.606061  10.633803
# F         12.666667  11.571429
# FC         6.157895  10.448276
# G         10.703704  10.871795
# GF        10.923077  11.480000
# PF         9.105263  11.188679
# PG        10.789474  10.977778
# SF        11.849315   9.972222
# SG        12.527273  12.829268

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='PTS', hue='Region', data=merged_df, errorbar=None, palette='viridis')
plt.xlabel('Position')
plt.ylabel('Points')
plt.title('Points Scored by Position and Region')
plt.legend()
plt.savefig("../mysite/PTS-Pos-Reg.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
pd.pivot_table(merged_df, values='FT_Percentage', index='Position', columns='Region', aggfunc='mean', fill_value=0)
# Out:
# Region        East      West
# Position
# C         0.670173  0.637596
# F         0.700000  0.347600
# FC        0.458375  0.633300
# G         0.649625  0.729938
# GF        0.733286  0.800412
# PF        0.687846  0.719926
# PG        0.758864  0.792227
# SF        0.723313  0.695091
# SG        0.726464  0.756000

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='FT_Percentage', hue='Region', data=merged_df, errorbar=None, palette='viridis')
plt.xlabel('Position')
plt.ylabel('Free Throw Percentage')
plt.title('Free Throw Percentage by Position and Region')
plt.legend()
plt.savefig("../mysite/FT-Pos-Reg.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
pd.pivot_table(merged_df, values='ThreeP_Percentage', index='Position', columns='Region', aggfunc='mean', fill_value=0)
# Out:
# Region        East      West
# Position
# C         0.083333  0.166667
# F         0.434714  0.183400
# FC        0.050000  0.250000
# G         0.358450  0.204182
# GF        0.381000  0.390909
# PF        0.333333  0.157895
# PG        0.332654  0.346344
# SF        0.304425  0.408200
# SG        0.292475  0.318344

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='ThreeP_Percentage', hue='Region', data=merged_df, errorbar=None, palette='viridis')
plt.xlabel('Position')
plt.ylabel('Three Pointer Percentage')
plt.title('Three Pointer Percentage by Position and Region')
plt.legend()
plt.savefig("../mysite/3P-Pos-Reg.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
pd.pivot_table(merged_df, values='FG_Percentage', index='Position', columns='Region', aggfunc='mean', fill_value=0)
# Out:
# Region        East      West
# Position
# C         0.534738  0.503826
# F         0.499722  0.550071
# FC        0.427158  0.509103
# G         0.397259  0.511154
# GF        0.428692  0.499640
# PF        0.460658  0.462302
# PG        0.488289  0.474867
# SF        0.456097  0.441361
# SG        0.466545  0.474925

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='FG_Percentage', hue='Region', data=merged_df, errorbar=None, palette='viridis')
plt.xlabel('Position')
plt.ylabel('Field Goal Percentage')
plt.title('Field Goal Percentage by Position and Region')
plt.legend()
plt.savefig("../mysite/FG-Pos-Reg.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='ORB', hue='Region', data=merged_df, errorbar=None, palette='viridis')
plt.xlabel('Position')
plt.ylabel('Offensive Rebounds')
plt.title('Offensive Rebounds by Position and Region')
plt.legend()
plt.savefig("../mysite/ORB-Pos-Reg.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='DRB', hue='Region', data=merged_df, errorbar=None, palette='viridis')
plt.xlabel('Position')
plt.ylabel('Defensive Rebounds')
plt.title('Defensive Rebounds by Position and Region')
plt.legend()
plt.savefig("../mysite/ORB-Pos-Reg.png")
plt.show()
# Out:
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
starter_df = merged_df[merged_df['Player_Type'] == "Starter"]
reserve_df = merged_df[merged_df['Player_Type'] == "Reserve"]
reserve_df.head()
# Out:
#            Players  MP  FG  FGA  ThreeP  ThreeP_Attempted  FT  FTA  ORB  DRB  \
# 4      Elvin Hayes  29   5   10       0                 0   2    2    2    3
# 5   Dan Roundfield  27   7   15       0                 0   4    9    9    4
# 6       Larry Bird  23   3    6       1                 2   0    0    3    3
# 7   Tiny Archibald  21   0    8       0                 0   2    3    1    2
# 8  Bill Cartwright  14   4    8       0                 0   0    0    1    2
#
#    ...  ThreeP_Percentage  FT_Percentage  Player_Type  Region  Year  Position  \
# 4  ...                NaN          1.000      Reserve    East  1980        FC
# 5  ...                NaN          0.444      Reserve    East  1980        PF
# 6  ...                0.5            NaN      Reserve    East  1980        SF
# 7  ...                NaN          0.667      Reserve    East  1980        PG
# 8  ...                NaN            NaN      Reserve    East  1980         C
#
# ...

# %%
pd.pivot_table(reserve_df, values='MP', index='Position', columns='Region', aggfunc='mean', fill_value=0)
# Out:
# Region         East       West
# Position
# C         15.631579  16.487179
# F         16.300000  17.416667
# FC        17.846154  17.538462
# G         16.058824  20.750000
# GF        15.333333  16.928571
# PF        17.655172  15.758621
# PG        18.541667  18.240000
# SF        16.571429  16.318182
# SG        17.531250  19.428571

# %%
print("Average Points of Starters =", starter_df['MP'].mean())
print("Average Points of Reserves =", reserve_df['MP'].mean())

plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='MP', hue="Region", data=reserve_df, errorbar=None, palette='viridis')
plt.xlabel('Player Position')
plt.ylabel('Average Minutes Played')
plt.title('Average Minutes Played by Position for Reserves')
plt.savefig("../mysite/Reserve-MP.png")
plt.show()
# Out:
# Average Points of Starters = 24.928327645051194
# Average Points of Reserves = 17.272727272727273
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
pd.pivot_table(reserve_df, values='PTS', index='Position', columns='Region', aggfunc='mean', fill_value=0)
# Out:
# Region        East       West
# Position
# C         8.763158   8.512821
# F         7.400000   9.750000
# FC        5.769231   8.538462
# G         8.647059  10.571429
# GF        7.000000   8.785714
# PF        8.344828   8.068966
# PG        9.375000   9.400000
# SF        9.628571   8.227273
# SG        9.125000  11.380952

# %%
print("Average Points of Starters =", starter_df['PTS'].mean())
print("Average Points of Reserves =", reserve_df['PTS'].mean())

plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='PTS', hue="Region", data=reserve_df, errorbar=None, palette='viridis')
plt.xlabel('Player Position')
plt.ylabel('Average Points')
plt.title('Average Points by Position for Reserves')
plt.savefig("../mysite/Reserve-PTS.png")
plt.show()
# Out:
# Average Points of Starters = 13.83617747440273
# Average Points of Reserves = 8.931203931203932
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
pd.pivot_table(reserve_df, values='TOV', index='Position', columns='Region', aggfunc='mean', fill_value=0)
# Out:
# Region        East      West
# Position
# C         1.210526  1.282051
# F         1.000000  0.750000
# FC        1.153846  0.923077
# G         1.411765  2.035714
# GF        0.666667  1.142857
# PF        0.931034  1.310345
# PG        2.000000  1.920000
# SF        0.857143  1.000000
# SG        1.250000  1.428571

# %%
print("Average Turnovers of Starters =", starter_df['TOV'].mean())
print("Average Turnovers of Reserves =", reserve_df['TOV'].mean())

plt.figure(figsize=(10, 6))
sns.barplot(x='Position', y='TOV', hue="Region", data=reserve_df, errorbar=None, palette='viridis')
plt.xlabel('Player Position')
plt.ylabel('Average Turnovers')
plt.title('Average Turnovers by Position for Reserves')
plt.savefig("../mysite/Reserve-TOV.png")
plt.show()
# Out:
# Average Turnovers of Starters = 2.368600682593857
# Average Turnovers of Reserves = 1.2923832923832923
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tori/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
